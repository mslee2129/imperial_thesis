# %%
import scipy.io as sio

# %%
test = sio.loadmat('C:/Users/ZEPHYRUS/Desktop/Imperial/Thesis/individual_project/data/nmed-t/eeg/song21_Imputed.mat')

# %%
# eeg = test[4]

print(test.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'data21', 'fs', 'subs21'])

# %%
print(test['fs'])
# Out:
# [[125]]

# %%
sub_01 = eeg[:,:,0]
print(sub_01.shape)
# Out:
# (125, 34795)

# %%
import matplotlib.pyplot as plt

# %%
print(sub_01.shape[1])
# Out:
# 34795

# %%
for i in range(eeg.shape[2]):
    sub = eeg[:,:,i]
    for j in range(0, sub.shape[1], 125):
        sample = sub[:,j:j+125]
        fig, ax = plt.subplots()
        img = ax.imshow(sample, cmap='magma', interpolation='nearest', aspect='auto')
        plt.savefig()
        break
    break
